# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline
import pandas
MD1 = numpy.loadtxt('Trial1/Depths_Trial1', delimiter = '|')
P1 = numpy.loadtxt('Trial1/Powers_Trial1', delimiter = '|')
S1 = numpy.loadtxt('Trial1/Speeds_Trial1', delimiter = '|')
T1 = numpy.loadtxt('Trial1/TMax_Trial1', delimiter = '|')

column_names = numpy.ndarray.tolist(S1)
row_names = numpy.ndarray.tolist(P1)

# %%
MD2 = numpy.loadtxt('Trial2/Depths_Trial2', delimiter = '|')
P2 = numpy.loadtxt('Trial2/Powers_Trial2', delimiter = '|')
S2 = numpy.loadtxt('Trial2/Speeds_Trial2', delimiter = '|')
T2 = numpy.loadtxt('Trial2/TMax_Trial2', delimiter = '|')

# %%
MD3 = numpy.loadtxt('Trial3/Depths_Trial3', delimiter = '|')
P3 = numpy.loadtxt('Trial3/Powers_Trial3', delimiter = '|')
S3 = numpy.loadtxt('Trial3/Speeds_Trial3', delimiter = '|')
T3 = numpy.loadtxt('Trial3/TMax_Trial3', delimiter = '|')

# %%
MD4 = numpy.loadtxt('Trial4/Depths_Trial4', delimiter = '|')
P4 = numpy.loadtxt('Trial4/Powers_Trial4', delimiter = '|')
S4 = numpy.loadtxt('Trial4/Speeds_Trial4', delimiter = '|')
T4 = numpy.loadtxt('Trial4/TMax_Trial4', delimiter = '|')

# %%
MD6 = numpy.loadtxt('Trial6/Depths_Trial6', delimiter = '|')
P6 = numpy.loadtxt('Trial6/Powers_Trial6', delimiter = '|')
S6 = numpy.loadtxt('Trial6/Speeds_Trial6', delimiter = '|')
T6 = numpy.loadtxt('Trial6/TMax_Trial6', delimiter = '|')

# %%
MD7 = numpy.loadtxt('Trial7/Depths_Trial7', delimiter = '|')
P7 = numpy.loadtxt('Trial7/Powers_Trial7', delimiter = '|')
S7 = numpy.loadtxt('Trial7/Speeds_Trial7', delimiter = '|')
T7 = numpy.loadtxt('Trial7/TMax_Trial7', delimiter = '|')
MW7 = numpy.loadtxt('Trial7/Widths_Trial7', delimiter = '|')

# %%
pyplot.rcParams['font.family'] = 'serif'
pyplot.rcParams['font.size'] = 16
pyplot.figure(figsize = (10,5))
pyplot.subplot(121)
y, x = numpy.meshgrid (S1, P1)
MeltDepth = pyplot.contourf(x, y, MD1, cmap = 'plasma')
pyplot.colorbar (MeltDepth);
pyplot.subplots_adjust(wspace = 0.5 )

pyplot.subplot(122)
TMaxC = pyplot.contourf(x,y, T1, cmap = 'plasma')
pyplot.colorbar ( TMaxC);

# %%
pandas.DataFrame(numpy.around(MD1+5,0), columns = column_names, index =row_names)
# Out:
#        0.15   0.20   0.25   0.30   0.35   0.50   0.65
# 3.0    65.0   61.0   56.0   52.0   48.0   39.0   34.0
# 5.0    80.0   76.0   72.0   68.0   64.0   53.0   46.0
# 7.0    89.0   86.0   83.0   79.0   75.0   64.0   56.0
# 9.0    96.0   93.0   90.0   87.0   83.0   73.0   64.0
# 10.0   98.0   96.0   93.0   90.0   87.0   77.0   67.0
# 12.0  103.0  101.0   98.0   95.0   93.0   83.0   74.0
# 15.0  109.0  107.0  105.0  102.0   99.0   91.0   83.0
# 17.0  112.0  110.0  108.0  106.0  103.0   95.0   87.0
# 20.0  116.0  115.0  112.0  110.0  107.0  100.0   93.0
# 25.0  122.0  120.0  118.0  116.0  114.0  107.0  101.0
# 30.0  126.0  124.0  123.0  121.0  119.0  112.0  107.0
# 35.0  130.0  128.0  127.0  125.0  123.0  117.0  112.0

# %%
pandas.DataFrame(numpy.around(T1+(0.2*T1),0), columns = column_names, index = row_names)
# Out:
#          0.15     0.20     0.25     0.30     0.35     0.50     0.65
# 3.0    6614.0   6104.0   5690.0   5351.0   5072.0   4450.0   4026.0
# 5.0   10783.0   9933.0   9243.0   8678.0   8213.0   7177.0   6470.0
# 7.0   14952.0  13762.0  12796.0  12005.0  11354.0   9904.0   8914.0
# 9.0   19122.0  17591.0  16349.0  15332.0  14495.0  12631.0  11358.0
# 10.0  21206.0  19506.0  18126.0  16996.0  16066.0  13994.0  12580.0
# 12.0  25376.0  23335.0  21679.0  20323.0  19207.0  16721.0  15024.0
# 15.0  31629.0  29079.0  27009.0  25314.0  23919.0  20811.0  18691.0
# 17.0  35799.0  32908.0  30562.0  28641.0  27060.0  23538.0  21135.0
# 20.0  42053.0  38652.0  35892.0  33632.0  31772.0  27628.0  24801.0
# 25.0  52476.0  48224.0  44775.0  41949.0  39625.0  34445.0  30911.0
# 30.0  62899.0  57797.0  53658.0  50267.0  47478.0  41262.0  37021.0
# 35.0  73322.0  67370.0  62540.0  58585.0  55331.0  48079.0  43131.0

# %%
pandas.DataFrame(numpy.around(MD3,0), columns = column_names, index =row_names)
# Out:
#        0.15   0.20   0.25   0.30   0.35   0.50  0.65
# 3.0    52.0   47.0   42.0   38.0   35.0   28.0  23.0
# 5.0    66.0   63.0   58.0   54.0   49.0   40.0  34.0
# 7.0    76.0   73.0   69.0   65.0   61.0   50.0  42.0
# 9.0    83.0   80.0   77.0   73.0   69.0   58.0  50.0
# 10.0   86.0   83.0   80.0   76.0   73.0   62.0  53.0
# 12.0   91.0   88.0   85.0   82.0   78.0   68.0  59.0
# 15.0   97.0   94.0   92.0   89.0   86.0   76.0  67.0
# 17.0  100.0   98.0   95.0   92.0   90.0   81.0  72.0
# 20.0  104.0  102.0  100.0   97.0   94.0   86.0  78.0
# 25.0  110.0  108.0  106.0  103.0  101.0   93.0  86.0
# 30.0  114.0  112.0  110.0  108.0  106.0   99.0  92.0
# 35.0  118.0  116.0  114.0  112.0  110.0  104.0  97.0

# %%
pandas.DataFrame(numpy.around(T2,0), columns = column_names, index = row_names)
# Out:
#          0.15     0.20     0.25     0.30     0.35     0.50     0.65
# 3.0    3059.0   2852.0   2678.0   2535.0   2414.0   2145.0   1959.0
# 5.0    4898.0   4554.0   4264.0   4025.0   3823.0   3375.0   3064.0
# 7.0    6737.0   6255.0   5849.0   5514.0   5232.0   4605.0   4170.0
# 9.0    8576.0   7956.0   7434.0   7004.0   6642.0   5835.0   5276.0
# 10.0   9495.0   8807.0   8227.0   7749.0   7346.0   6451.0   5828.0
# 12.0  11334.0  10508.0   9813.0   9239.0   8755.0   7681.0   6934.0
# 15.0  14093.0  13061.0  12191.0  11474.0  10869.0   9526.0   8593.0
# 17.0  15932.0  14762.0  13776.0  12964.0  12279.0  10756.0   9698.0
# 20.0  18690.0  17314.0  16154.0  15199.0  14392.0  12601.0  11357.0
# 25.0  23288.0  21568.0  20118.0  18923.0  17916.0  15676.0  14121.0
# 30.0  27886.0  25821.0  24081.0  22648.0  21439.0  18752.0  16885.0
# 35.0  32483.0  30075.0  28045.0  26372.0  24962.0  21827.0  19650.0

# %%
pandas.DataFrame(numpy.around(((MD2-MD1)/MD1)*100,0), columns = column_names, index = row_names)
# Out:
#       0.15  0.20  0.25  0.30  0.35  0.50  0.65
# 3.0  -28.0 -30.0 -32.0 -33.0 -33.0 -35.0 -37.0
# 5.0  -21.0 -23.0 -25.0 -27.0 -28.0 -30.0 -31.0
# 7.0  -17.0 -19.0 -21.0 -23.0 -25.0 -27.0 -28.0
# 9.0  -15.0 -16.0 -18.0 -20.0 -22.0 -26.0 -27.0
# 10.0 -14.0 -15.0 -17.0 -19.0 -21.0 -25.0 -26.0
# 12.0 -12.0 -13.0 -15.0 -16.0 -19.0 -24.0 -26.0
# 15.0 -11.0 -12.0 -13.0 -14.0 -16.0 -21.0 -25.0
# 17.0 -10.0 -11.0 -12.0 -13.0 -15.0 -19.0 -23.0
# 20.0  -9.0 -10.0 -11.0 -12.0 -13.0 -17.0 -22.0
# 25.0  -8.0  -8.0  -9.0 -10.0 -11.0 -14.0 -19.0
# 30.0  -7.0  -7.0  -8.0  -9.0  -9.0 -12.0 -16.0
# 35.0  -6.0  -7.0  -7.0  -8.0  -8.0 -11.0 -14.0

# %%
pandas.DataFrame(numpy.around(MD3,0), columns = column_names, index =row_names)
# Out:
#        0.15   0.20   0.25   0.30   0.35   0.50  0.65
# 3.0    52.0   47.0   42.0   38.0   35.0   28.0  23.0
# 5.0    66.0   63.0   58.0   54.0   49.0   40.0  34.0
# 7.0    76.0   73.0   69.0   65.0   61.0   50.0  42.0
# 9.0    83.0   80.0   77.0   73.0   69.0   58.0  50.0
# 10.0   86.0   83.0   80.0   76.0   73.0   62.0  53.0
# 12.0   91.0   88.0   85.0   82.0   78.0   68.0  59.0
# 15.0   97.0   94.0   92.0   89.0   86.0   76.0  67.0
# 17.0  100.0   98.0   95.0   92.0   90.0   81.0  72.0
# 20.0  104.0  102.0  100.0   97.0   94.0   86.0  78.0
# 25.0  110.0  108.0  106.0  103.0  101.0   93.0  86.0
# 30.0  114.0  112.0  110.0  108.0  106.0   99.0  92.0
# 35.0  118.0  116.0  114.0  112.0  110.0  104.0  97.0

# %%
pandas.DataFrame(numpy.around(T3,0), columns = column_names, index = row_names)
# Out:
#          0.15     0.20     0.25     0.30     0.35     0.50     0.65
# 3.0    4209.0   3890.0   3631.0   3419.0   3245.0   2856.0   2591.0
# 5.0    6814.0   6283.0   5852.0   5499.0   5208.0   4561.0   4119.0
# 7.0    9420.0   8676.0   8073.0   7578.0   7171.0   6265.0   5646.0
# 9.0   12026.0  11069.0  10293.0   9658.0   9135.0   7969.0   7174.0
# 10.0  13329.0  12266.0  11404.0  10697.0  10116.0   8821.0   7938.0
# 12.0  15935.0  14659.0  13624.0  12777.0  12080.0  10526.0   9465.0
# 15.0  19843.0  18249.0  16955.0  15896.0  15024.0  13082.0  11757.0
# 17.0  22449.0  20642.0  19176.0  17976.0  16988.0  14786.0  13284.0
# 20.0  26358.0  24232.0  22507.0  21095.0  19933.0  17343.0  15576.0
# 25.0  32872.0  30215.0  28059.0  26293.0  24841.0  21603.0  19394.0
# 30.0  39387.0  36198.0  33611.0  31492.0  29749.0  25864.0  23213.0
# 35.0  45901.0  42181.0  39163.0  36691.0  34657.0  30124.0  27032.0

# %%
pandas.DataFrame(numpy.around(((T3-T1)/T1)*100,0), columns = column_names, index =row_names)
# Out:
#       0.15  0.20  0.25  0.30  0.35  0.50  0.65
# 3.0  -24.0 -24.0 -23.0 -23.0 -23.0 -23.0 -23.0
# 5.0  -24.0 -24.0 -24.0 -24.0 -24.0 -24.0 -24.0
# 7.0  -24.0 -24.0 -24.0 -24.0 -24.0 -24.0 -24.0
# 9.0  -25.0 -24.0 -24.0 -24.0 -24.0 -24.0 -24.0
# 10.0 -25.0 -25.0 -25.0 -24.0 -24.0 -24.0 -24.0
# 12.0 -25.0 -25.0 -25.0 -25.0 -25.0 -24.0 -24.0
# 15.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0
# 17.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0
# 20.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0
# 25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0
# 30.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0
# 35.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0 -25.0

# %%
pandas.DataFrame(MD1-MD3, columns = column_names, index =row_names)
# Out:
#       0.15  0.20  0.25  0.30  0.35  0.50  0.65
# 3.0    8.4   8.5   8.9   8.5   7.6   6.2   5.8
# 5.0    8.4   8.5   8.9   9.4   9.4   8.0   7.1
# 7.0    8.0   8.5   9.0   9.3   9.8   8.9   8.5
# 9.0    7.6   8.0   8.5   8.9   9.4  10.3   8.9
# 10.0   7.5   8.0   8.5   8.9   9.4  10.2   9.4
# 12.0   7.5   8.0   8.4   8.4   9.4  10.2  10.7
# 15.0   7.5   7.6   8.0   8.5   8.9   9.8  11.2
# 17.0   7.5   7.5   7.6   8.5   8.5   9.4  10.7
# 20.0   7.2   7.6   7.5   8.0   8.0   9.3  10.2
# 25.0   7.1   7.1   7.5   7.6   8.0   8.9   9.8
# 30.0   7.2   7.2   7.1   7.6   7.6   8.4   9.4
# 35.0   7.1   6.6   7.1   7.6   7.6   8.0   9.4

# %%
numpy.mean(MD1-MD3)
# Out:
# 8.388095238095238

# %%
numpy.min(MD1-MD3)
# Out:
# 5.800000000000001

# %%
pandas.DataFrame(numpy.around(((MD4-MD3)/MD3)*100,0), columns = column_names, index =row_names)
# Out:
#       0.15  0.20  0.25  0.30  0.35  0.50  0.65
# 3.0  -34.0 -35.0 -36.0 -37.0 -39.0 -41.0 -42.0
# 5.0  -24.0 -27.0 -29.0 -31.0 -31.0 -32.0 -34.0
# 7.0  -20.0 -22.0 -24.0 -26.0 -28.0 -29.0 -30.0
# 9.0  -18.0 -19.0 -22.0 -24.0 -26.0 -28.0 -29.0
# 10.0 -16.0 -18.0 -20.0 -22.0 -25.0 -27.0 -28.0
# 12.0 -15.0 -16.0 -18.0 -20.0 -22.0 -26.0 -27.0
# 15.0 -13.0 -14.0 -16.0 -17.0 -19.0 -25.0 -26.0
# 17.0 -12.0 -13.0 -14.0 -16.0 -18.0 -23.0 -25.0
# 20.0 -11.0 -12.0 -13.0 -14.0 -16.0 -21.0 -25.0
# 25.0  -9.0 -10.0 -11.0 -12.0 -13.0 -18.0 -22.0
# 30.0  -8.0  -9.0 -10.0 -11.0 -12.0 -16.0 -20.0
# 35.0  -7.0  -8.0  -9.0  -9.0 -11.0 -14.0 -17.0

# %%
pandas.DataFrame(numpy.around(((MD3-MD1)/MD1)*100,0), columns = column_names, index =row_names)
# Out:
#       0.15  0.20  0.25  0.30  0.35  0.50  0.65
# 3.0  -14.0 -15.0 -17.0 -18.0 -18.0 -18.0 -20.0
# 5.0  -11.0 -12.0 -13.0 -15.0 -16.0 -17.0 -17.0
# 7.0  -10.0 -10.0 -12.0 -13.0 -14.0 -15.0 -17.0
# 9.0   -8.0  -9.0 -10.0 -11.0 -12.0 -15.0 -15.0
# 10.0  -8.0  -9.0 -10.0 -10.0 -11.0 -14.0 -15.0
# 12.0  -8.0  -8.0  -9.0  -9.0 -11.0 -13.0 -15.0
# 15.0  -7.0  -7.0  -8.0  -9.0  -9.0 -11.0 -14.0
# 17.0  -7.0  -7.0  -7.0  -8.0  -9.0 -10.0 -13.0
# 20.0  -6.0  -7.0  -7.0  -8.0  -8.0 -10.0 -12.0
# 25.0  -6.0  -6.0  -7.0  -7.0  -7.0  -9.0 -10.0
# 30.0  -6.0  -6.0  -6.0  -7.0  -7.0  -8.0  -9.0
# 35.0  -6.0  -5.0  -6.0  -6.0  -6.0  -7.0  -9.0

# %%
pandas.DataFrame(numpy.around(MD2,0), columns = column_names, index =row_names)
# Out:
#        0.15   0.20   0.25   0.30   0.35   0.50  0.65
# 3.0    43.0   39.0   35.0   31.0   28.0   22.0  18.0
# 5.0    59.0   55.0   50.0   46.0   42.0   34.0  28.0
# 7.0    70.0   66.0   62.0   57.0   53.0   43.0  36.0
# 9.0    78.0   74.0   70.0   66.0   61.0   50.0  43.0
# 10.0   81.0   78.0   74.0   69.0   65.0   54.0  46.0
# 12.0   86.0   83.0   80.0   76.0   71.0   60.0  51.0
# 15.0   93.0   90.0   87.0   83.0   79.0   68.0  59.0
# 17.0   97.0   94.0   91.0   87.0   84.0   73.0  63.0
# 20.0  102.0   99.0   96.0   93.0   90.0   79.0  69.0
# 25.0  108.0  106.0  103.0  100.0   97.0   87.0  78.0
# 30.0  113.0  110.0  108.0  106.0  103.0   94.0  86.0
# 35.0  117.0  115.0  113.0  110.0  108.0  100.0  92.0

# %%
pandas.DataFrame(numpy.around(MD4,0), columns = column_names, index =row_names)
# Out:
#        0.15   0.20   0.25   0.30  0.35  0.50  0.65
# 3.0    34.0   31.0   27.0   24.0  21.0  16.0  13.0
# 5.0    50.0   46.0   41.0   37.0  34.0  27.0  23.0
# 7.0    61.0   57.0   52.0   48.0  44.0  35.0  30.0
# 9.0    69.0   65.0   60.0   56.0  51.0  42.0  36.0
# 10.0   72.0   68.0   64.0   59.0  55.0  45.0  38.0
# 12.0   78.0   74.0   70.0   66.0  61.0  50.0  43.0
# 15.0   85.0   81.0   78.0   74.0  69.0  58.0  49.0
# 17.0   88.0   85.0   82.0   78.0  74.0  62.0  54.0
# 20.0   93.0   90.0   87.0   83.0  79.0  68.0  59.0
# 25.0   99.0   97.0   94.0   91.0  87.0  77.0  67.0
# 30.0  105.0  102.0  100.0   97.0  94.0  83.0  74.0
# 35.0  109.0  107.0  104.0  102.0  98.0  89.0  80.0

# %%
pandas.DataFrame(numpy.around(((T2-T1)/T1)*100,0))
# Out:
#        0     1     2     3     4     5     6
# 0  -45.0 -44.0 -44.0 -43.0 -43.0 -42.0 -42.0
# 1  -45.0 -45.0 -45.0 -44.0 -44.0 -44.0 -43.0
# 2  -46.0 -45.0 -45.0 -45.0 -45.0 -44.0 -44.0
# 3  -46.0 -46.0 -45.0 -45.0 -45.0 -45.0 -44.0
# 4  -46.0 -46.0 -46.0 -45.0 -45.0 -45.0 -44.0
# 5  -46.0 -46.0 -46.0 -45.0 -45.0 -45.0 -45.0
# 6  -47.0 -46.0 -46.0 -46.0 -45.0 -45.0 -45.0
# 7  -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0
# 8  -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0
# 9  -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0
# 10 -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0
# 11 -47.0 -46.0 -46.0 -46.0 -46.0 -46.0 -45.0

# %%
pandas.DataFrame(numpy.around(T4,0), columns = column_names, index = row_names)
# Out:
#          0.15     0.20     0.25     0.30     0.35     0.50     0.65
# 3.0    2369.0   2214.0   2084.0   1976.0   1885.0   1684.0   1544.0
# 5.0    3748.0   3490.0   3273.0   3093.0   2942.0   2606.0   2373.0
# 7.0    5127.0   4766.0   4462.0   4211.0   3999.0   3529.0   3202.0
# 9.0    6507.0   6042.0   5651.0   5328.0   5056.0   4452.0   4032.0
# 10.0   7196.0   6680.0   6245.0   5887.0   5585.0   4913.0   4446.0
# 12.0   8576.0   7956.0   7434.0   7004.0   6642.0   5835.0   5276.0
# 15.0  10645.0   9870.0   9218.0   8680.0   8227.0   7219.0   6520.0
# 17.0  12024.0  11146.0  10407.0   9798.0   9284.0   8142.0   7349.0
# 20.0  14093.0  13061.0  12191.0  11474.0  10869.0   9526.0   8593.0
# 25.0  17541.0  16251.0  15163.0  14267.0  13512.0  11832.0  10666.0
# 30.0  20989.0  19441.0  18136.0  17061.0  16154.0  14139.0  12739.0
# 35.0  24437.0  22631.0  21109.0  19854.0  18796.0  16445.0  14812.0

# %%
pandas.DataFrame(numpy.around(((T4-T3)/T3)*100,0), columns = column_names, index = row_names)
# Out:
#       0.15  0.20  0.25  0.30  0.35  0.50  0.65
# 3.0  -44.0 -43.0 -43.0 -42.0 -42.0 -41.0 -40.0
# 5.0  -45.0 -44.0 -44.0 -44.0 -44.0 -43.0 -42.0
# 7.0  -46.0 -45.0 -45.0 -44.0 -44.0 -44.0 -43.0
# 9.0  -46.0 -45.0 -45.0 -45.0 -45.0 -44.0 -44.0
# 10.0 -46.0 -46.0 -45.0 -45.0 -45.0 -44.0 -44.0
# 12.0 -46.0 -46.0 -45.0 -45.0 -45.0 -45.0 -44.0
# 15.0 -46.0 -46.0 -46.0 -45.0 -45.0 -45.0 -45.0
# 17.0 -46.0 -46.0 -46.0 -45.0 -45.0 -45.0 -45.0
# 20.0 -47.0 -46.0 -46.0 -46.0 -45.0 -45.0 -45.0
# 25.0 -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0
# 30.0 -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0
# 35.0 -47.0 -46.0 -46.0 -46.0 -46.0 -45.0 -45.0

# %%
pandas.DataFrame(numpy.around(((T4-T1)/T1)*100,0))
# Out:
#        0     1     2     3     4     5     6
# 0  -57.0 -56.0 -56.0 -56.0 -55.0 -55.0 -54.0
# 1  -58.0 -58.0 -58.0 -57.0 -57.0 -56.0 -56.0
# 2  -59.0 -58.0 -58.0 -58.0 -58.0 -57.0 -57.0
# 3  -59.0 -59.0 -59.0 -58.0 -58.0 -58.0 -57.0
# 4  -59.0 -59.0 -59.0 -58.0 -58.0 -58.0 -58.0
# 5  -59.0 -59.0 -59.0 -59.0 -59.0 -58.0 -58.0
# 6  -60.0 -59.0 -59.0 -59.0 -59.0 -58.0 -58.0
# 7  -60.0 -59.0 -59.0 -59.0 -59.0 -58.0 -58.0
# 8  -60.0 -59.0 -59.0 -59.0 -59.0 -59.0 -58.0
# 9  -60.0 -60.0 -59.0 -59.0 -59.0 -59.0 -59.0
# 10 -60.0 -60.0 -59.0 -59.0 -59.0 -59.0 -59.0
# 11 -60.0 -60.0 -59.0 -59.0 -59.0 -59.0 -59.0

# %%
pandas.DataFrame(numpy.around(T2,0), columns = column_names, index = row_names)
# Out:
#          0.15     0.20     0.25     0.30     0.35     0.50     0.65
# 3.0    3059.0   2852.0   2678.0   2535.0   2414.0   2145.0   1959.0
# 5.0    4898.0   4554.0   4264.0   4025.0   3823.0   3375.0   3064.0
# 7.0    6737.0   6255.0   5849.0   5514.0   5232.0   4605.0   4170.0
# 9.0    8576.0   7956.0   7434.0   7004.0   6642.0   5835.0   5276.0
# 10.0   9495.0   8807.0   8227.0   7749.0   7346.0   6451.0   5828.0
# 12.0  11334.0  10508.0   9813.0   9239.0   8755.0   7681.0   6934.0
# 15.0  14093.0  13061.0  12191.0  11474.0  10869.0   9526.0   8593.0
# 17.0  15932.0  14762.0  13776.0  12964.0  12279.0  10756.0   9698.0
# 20.0  18690.0  17314.0  16154.0  15199.0  14392.0  12601.0  11357.0
# 25.0  23288.0  21568.0  20118.0  18923.0  17916.0  15676.0  14121.0
# 30.0  27886.0  25821.0  24081.0  22648.0  21439.0  18752.0  16885.0
# 35.0  32483.0  30075.0  28045.0  26372.0  24962.0  21827.0  19650.0

# %%
pandas.DataFrame(numpy.around( ((T1-T2)/T1 )* 100, 0)) # percent decrease from powder to solid
# Out:
#        0     1     2     3     4     5     6
# 0   45.0  44.0  44.0  43.0  43.0  42.0  42.0
# 1   45.0  45.0  45.0  44.0  44.0  44.0  43.0
# 2   46.0  45.0  45.0  45.0  45.0  44.0  44.0
# 3   46.0  46.0  45.0  45.0  45.0  45.0  44.0
# 4   46.0  46.0  46.0  45.0  45.0  45.0  44.0
# 5   46.0  46.0  46.0  45.0  45.0  45.0  45.0
# 6   47.0  46.0  46.0  46.0  45.0  45.0  45.0
# 7   47.0  46.0  46.0  46.0  46.0  45.0  45.0
# 8   47.0  46.0  46.0  46.0  46.0  45.0  45.0
# 9   47.0  46.0  46.0  46.0  46.0  45.0  45.0
# 10  47.0  46.0  46.0  46.0  46.0  45.0  45.0
# 11  47.0  46.0  46.0  46.0  46.0  46.0  45.0

# %%
pandas.DataFrame(numpy.around(( MD1 - MD2 ) / MD1 * 100, 0)) # percent decrease from powder to solid
# Out:
#        0     1     2     3     4     5     6
# 0   28.0  30.0  32.0  33.0  33.0  35.0  37.0
# 1   21.0  23.0  25.0  27.0  28.0  30.0  31.0
# 2   17.0  19.0  21.0  23.0  25.0  27.0  28.0
# 3   15.0  16.0  18.0  20.0  22.0  26.0  27.0
# 4   14.0  15.0  17.0  19.0  21.0  25.0  26.0
# 5   12.0  13.0  15.0  16.0  19.0  24.0  26.0
# 6   11.0  12.0  13.0  14.0  16.0  21.0  25.0
# 7   10.0  11.0  12.0  13.0  15.0  19.0  23.0
# 8    9.0  10.0  11.0  12.0  13.0  17.0  22.0
# 9    8.0   8.0   9.0  10.0  11.0  14.0  19.0
# 10   7.0   7.0   8.0   9.0   9.0  12.0  16.0
# 11   6.0   7.0   7.0   8.0   8.0  11.0  14.0

# %%
pandas.DataFrame(MD3), pandas.DataFrame(T3)
# Out:
# (        0      1      2      3      4      5     6
#  0    51.7   47.2   42.3   38.3   35.2   28.1  23.2
#  1    66.4   62.8   58.4   53.9   49.4   40.1  34.3
#  2    76.2   72.6   69.0   64.6   60.6   49.9  42.3
#  3    83.3   80.2   76.6   73.1   69.0   57.9  49.9
#  4    86.0   83.3   79.7   76.2   72.6   61.5  53.0
#  5    90.9   88.2   85.1   82.0   78.4   68.2  58.8
#  6    96.7   94.4   91.8   88.6   85.5   76.2  66.8
#  7    99.8   97.6   95.3   92.2   89.5   80.6  71.7
#  8   104.2  102.0   99.8   97.1   94.4   86.0  78.0
#  9   109.6  107.8  105.6  103.3  100.7   93.1  86.0
#  10  114.0  112.2  110.5  108.2  106.0   98.9  92.2
#  11  117.6  116.3  114.5  112.2  110.0  103.8  97.1,
#                 0             1             2             3             4  \
#  0    4208.680927   3889.828551   3631.094516   3419.206882   3244.894113
#  1    6814.468212   6283.047585   5851.824194   5498.678136   5208.156855
# ...

# %%
pandas.DataFrame(MD4), pandas.DataFrame(T4)
# Out:
# (        0      1      2      3     4     5     6
#  0    34.3   30.7   27.2   24.1  21.4  16.5  13.4
#  1    50.3   45.9   41.4   37.4  34.3  27.2  22.7
#  2    60.6   56.6   52.1   47.7  43.7  35.2  29.8
#  3    68.6   64.6   60.1   55.7  51.2  41.9  35.6
#  4    72.2   68.2   63.7   59.2  54.8  45.0  38.3
#  5    77.5   73.9   69.9   65.5  61.0  50.3  43.2
#  6    84.6   81.1   77.5   73.5  69.0  57.5  49.4
#  7    88.2   85.1   81.5   77.5  73.5  61.9  53.5
#  8    93.1   90.0   86.9   83.3  79.3  67.7  58.8
#  9    99.3   97.1   94.0   90.9  87.3  76.6  66.8
#  10  104.7  102.4   99.8   96.7  93.5  83.3  73.9
#  11  109.1  106.9  104.2  101.6  98.4  89.1  80.2,
#                 0             1             2             3             4  \
#  0    2368.926961   2214.080441   2083.604657   1976.083041   1885.398974
#  1    3748.211601   3490.134069   3272.674429   3093.471735   2942.331623
#  2    5127.496242   4766.187696   4461.744201   4210.860430   3999.264273
# ...

# %%
pyplot.rcParams['font.family'] = 'serif'
pyplot.rcParams['font.size'] = 16
pyplot.figure(figsize = (10,5))
pyplot.subplot(121)
y, x = numpy.meshgrid (S2, P2)
MeltDepth2 = pyplot.contourf(x, y, MD2, cmap = 'plasma')
pyplot.colorbar (MeltDepth);
pyplot.subplots_adjust(wspace = 0.5 )

pyplot.subplot(122)
TMaxC2 = pyplot.contourf(x,y, T2, cmap = 'plasma')
pyplot.colorbar ( TMaxC);

# %%
numpy.max(T2)
# Out:
# 32483.308278226188

# %%
numpy.max(T1)
# Out:
# 61101.70330823576

# %%
numpy.max(MD1)
# Out:
# 124.7

# %%
numpy.max(MD2)
# Out:
# 116.7

# %%
MD2
# Out:
# array([[ 43.2,  38.8,  34.7,  31.2,  28.5,  22.3,  18.3],
#        [ 59.2,  54.8,  50.3,  45.9,  42.3,  33.9,  28.5],
#        [ 69.9,  65.9,  61.5,  57. ,  52.6,  42.8,  36.5],
#        [ 77.5,  73.9,  69.9,  65.5,  61. ,  50.3,  43.2],
#        [ 80.6,  77.5,  73.5,  69. ,  65. ,  53.5,  45.9],
#        [ 86.4,  83.3,  79.7,  75.7,  71.3,  59.7,  51.2],
#        [ 93.1,  90. ,  86.9,  83.3,  79.3,  67.7,  58.8],
#        [ 96.7,  94. ,  90.9,  87.3,  83.7,  72.6,  63.3],
#        [101.6,  98.9,  95.8,  92.7,  89.5,  78.8,  69. ],
#        [107.8, 105.6, 102.9,  99.8,  97.1,  87.3,  78. ],
#        [112.7, 110.5, 108.2, 105.6, 102.9,  94. ,  85.5],
#        [116.7, 114.9, 112.7, 110. , 107.8,  99.8,  91.8]])

# %%
import pandas

pandas.DataFrame ( T2)
# Out:
#                0             1             2             3             4  \
# 0    3058.569281   2852.107255   2678.139543   2534.777388   2413.865299
# 1    4897.615468   4553.512091   4263.565905   4024.628981   3823.108831
# 2    6736.661656   6254.916928   5848.992267   5514.480573   5232.352364
# 3    8575.707843   7956.321765   7434.418630   7004.332165   6641.595896
# 4    9495.230937   8807.024183   8227.131811   7749.257961   7346.217662
# 5   11334.277124  10508.429020   9812.558173   9239.109553   8755.461195
# 6   14092.846405  13060.536274  12190.697716  11473.886942  10869.326493
# 7   15931.892592  14761.941111  13776.124078  12963.738534  12278.570026
# 8   18690.461873  17314.048366  16154.263621  15198.515922  14392.435325
# 9   23288.077342  21567.560457  20117.829527  18923.144903  17915.544156
# 10  27885.692810  25821.072549  24081.395432  22647.773883  21438.652987
# 11  32483.308278  30074.584640  28044.961337  26372.402864  24961.761818
#
# ...

# %%
MD2
# Out:
# array([[ 43.2,  38.8,  34.7,  31.2,  28.5,  22.3,  18.3],
#        [ 59.2,  54.8,  50.3,  45.9,  42.3,  33.9,  28.5],
#        [ 69.9,  65.9,  61.5,  57. ,  52.6,  42.8,  36.5],
#        [ 77.5,  73.9,  69.9,  65.5,  61. ,  50.3,  43.2],
#        [ 80.6,  77.5,  73.5,  69. ,  65. ,  53.5,  45.9],
#        [ 86.4,  83.3,  79.7,  75.7,  71.3,  59.7,  51.2],
#        [ 93.1,  90. ,  86.9,  83.3,  79.3,  67.7,  58.8],
#        [ 96.7,  94. ,  90.9,  87.3,  83.7,  72.6,  63.3],
#        [101.6,  98.9,  95.8,  92.7,  89.5,  78.8,  69. ],
#        [107.8, 105.6, 102.9,  99.8,  97.1,  87.3,  78. ],
#        [112.7, 110.5, 108.2, 105.6, 102.9,  94. ,  85.5],
#        [116.7, 114.9, 112.7, 110. , 107.8,  99.8,  91.8]])

# %%
(78-88)/88
# Out:
# -0.11363636363636363

# %%
(12080-16000)/16000 *100
# Out:
# -24.5

# %%
MD8 = numpy.loadtxt('Trial8/Depths_Trial8', delimiter = '|')
P8 = numpy.loadtxt('Trial8/Powers_Trial8', delimiter = '|')
S8 = numpy.loadtxt('Trial8/Speeds_Trial8', delimiter = '|')
T8 = numpy.loadtxt('Trial8/TMax_Trial8', delimiter = '|')

# %%
pandas.DataFrame(MD1-MD3)
# Out:
#       0    1    2    3    4     5     6
# 0   8.4  8.5  8.9  8.5  7.6   6.2   5.8
# 1   8.4  8.5  8.9  9.4  9.4   8.0   7.1
# 2   8.0  8.5  9.0  9.3  9.8   8.9   8.5
# 3   7.6  8.0  8.5  8.9  9.4  10.3   8.9
# 4   7.5  8.0  8.5  8.9  9.4  10.2   9.4
# 5   7.5  8.0  8.4  8.4  9.4  10.2  10.7
# 6   7.5  7.6  8.0  8.5  8.9   9.8  11.2
# 7   7.5  7.5  7.6  8.5  8.5   9.4  10.7
# 8   7.2  7.6  7.5  8.0  8.0   9.3  10.2
# 9   7.1  7.1  7.5  7.6  8.0   8.9   9.8
# 10  7.2  7.2  7.1  7.6  7.6   8.4   9.4
# 11  7.1  6.6  7.1  7.6  7.6   8.0   9.4

# %%
numpy.mean(MD1-MD3)
# Out:
# 8.388095238095238

# %%
pandas.DataFrame(numpy.around(MD6,0), columns = numpy.ndarray.tolist(S6), index = numpy.ndarray.tolist(P6) )
# Out:
#        0.20   0.35   0.50
# 10.0   91.0   82.0   72.0
# 15.0  102.0   94.0   86.0
# 20.0  110.0  102.0   95.0
# 25.0  115.0  109.0  102.0

# %%
pandas.DataFrame(numpy.around(MD7,0), columns = numpy.ndarray.tolist(S7), index = numpy.ndarray.tolist(P7) )
# Out:
#        0.20   0.35   0.50
# 10.0   97.0   89.0   80.0
# 15.0  108.0  101.0   93.0
# 20.0  115.0  109.0  102.0
# 25.0  120.0  115.0  109.0

# %%
pandas.DataFrame(numpy.around(T6,0), columns = numpy.ndarray.tolist(S6), index = numpy.ndarray.tolist(P6) )
# Out:
#          0.20     0.35     0.50
# 10.0  16255.0  13388.0  11662.0
# 15.0  24232.0  19933.0  17343.0
# 20.0  32210.0  26477.0  23023.0
# 25.0  40187.0  33021.0  28704.0

# %%
pandas.DataFrame(numpy.around(T7,0), columns = numpy.ndarray.tolist(S7), index = numpy.ndarray.tolist(P7) )
# Out:
#          0.20     0.35     0.50
# 10.0  20243.0  16661.0  14502.0
# 15.0  30215.0  24841.0  21603.0
# 20.0  40187.0  33021.0  28704.0
# 25.0  50159.0  41201.0  35805.0

# %%
pandas.DataFrame(numpy.around(MD6,0), columns = numpy.ndarray.tolist(S6), index = numpy.ndarray.tolist(P6) )
# Out:
#        0.20   0.35   0.50
# 10.0   91.0   82.0   72.0
# 15.0  102.0   94.0   86.0
# 20.0  110.0  102.0   95.0
# 25.0  115.0  109.0  102.0

# %%
pandas.DataFrame(numpy.around(MD7,0), columns = numpy.ndarray.tolist(S6), index = numpy.ndarray.tolist(P6) )
# Out:
#        0.20   0.35   0.50
# 10.0   97.0   89.0   80.0
# 15.0  108.0  101.0   93.0
# 20.0  115.0  109.0  102.0
# 25.0  120.0  115.0  109.0

# %%
pandas.DataFrame(numpy.around(MD7[:,1:],0))
# Out:
#        0      1
# 0   89.0   80.0
# 1  101.0   93.0
# 2  109.0  102.0
# 3  115.0  109.0

# %%
pandas.DataFrame(numpy.around(T7,0), columns = numpy.ndarray.tolist(S6), index = numpy.ndarray.tolist(P6) )
# Out:
#          0.20     0.35     0.50
# 10.0  20243.0  16661.0  14502.0
# 15.0  30215.0  24841.0  21603.0
# 20.0  40187.0  33021.0  28704.0
# 25.0  50159.0  41201.0  35805.0

# %%
pandas.DataFrame(numpy.around(MD8,0), columns = numpy.ndarray.tolist(S6), index = numpy.ndarray.tolist(P6) )
# Out:
#        0.20   0.35   0.50
# 10.0  102.0   94.0   86.0
# 15.0  112.0  106.0   99.0
# 20.0  119.0  114.0  107.0
# 25.0  125.0  119.0  114.0

# %%
((MD7-MD6)/MD6 * 100).mean()
# Out:
# 6.814609753025824

# %%
((T8-T7)/T7)*100
# Out:
# array([[19.70360845, 19.63986724, 19.58626662],
#        [19.8014247 , 19.75846173, 19.72226259],
#        [19.85069793, 19.8182977 , 19.79097126],
#        [19.88037975, 19.85437355, 19.83242673]])

# %%
((T7-T6)/T6)*100
# Out:
# array([[24.53859765, 24.43981433, 24.35686766],
#        [24.69049434, 24.62373249, 24.56753669],
#        [24.76715007, 24.71673353, 24.67424374],
#        [24.81337241, 24.77287212, 24.73871407]])

# %%
T8.max()
# Out:
# 60130.47585215104

# %%
T7.max()
# Out:
# 50158.72987679253

# %%
5/15
# Out:
# 0.3333333333333333

# %%
-0.15/0.5
# Out:
# -0.3

# %%
MW7
# Out:
# array([[109.6,  99.3,  88.6],
#        [120.7, 111.8, 102.9],
#        [128.3, 120.3, 112.2],
#        [133.6, 126.5, 119.4]])

# %%
MD9 = numpy.loadtxt('Trial9/Depths_Trial9', delimiter = '|')
P9 = numpy.loadtxt('Trial9/Powers_Trial9', delimiter = '|')
S9 = numpy.loadtxt('Trial9/Speeds_Trial9', delimiter = '|')
T9 = numpy.loadtxt('Trial9/TMax_Trial9', delimiter = '|')

# %%
pandas.DataFrame(MD9, columns = numpy.ndarray.tolist(S9), index = numpy.ndarray.tolist(P9))
# Out:
#        0.30   0.35   0.40   0.45   0.50
# 5.0    70.4   66.4   62.4   58.4   55.2
# 10.0   91.8   89.1   86.0   82.9   79.7
# 15.0  103.3  100.7   98.4   95.8   93.1
# 20.0  110.9  108.7  106.5  104.2  102.0
# 25.0  116.7  114.9  112.7  110.9  108.7

# %%
MD10 = numpy.loadtxt('Trial10/Depths_Trial10', delimiter = '|')
MW10 = numpy.loadtxt('Trial10/Widths_Trial10', delimiter = '|')
P10 = numpy.loadtxt('Trial10/Powers_Trial10', delimiter = '|')
S10 = numpy.loadtxt('Trial10/Speeds_Trial10', delimiter = '|')
T10 = numpy.loadtxt('Trial10/TMax_Trial10', delimiter = '|')

# %%
pandas.DataFrame(MD10, columns = numpy.ndarray.tolist(S10), index = numpy.ndarray.tolist(P10))
# Out:
#        0.20   0.35   0.50   0.65
# 5.0    78.0   66.4   55.2   47.2
# 10.0   97.1   89.1   79.7   70.8
# 15.0  107.8  100.7   93.1   86.0
# 20.0  114.9  108.7  102.0   95.8
# 25.0  120.3  114.9  108.7  102.9

# %%
pandas.DataFrame(MW10, columns = numpy.ndarray.tolist(S10), index = numpy.ndarray.tolist(P10))
# Out:
#        0.20   0.35   0.50   0.65
# 5.0    89.5   76.2   65.9   61.0
# 10.0  109.6   99.3   88.6   79.3
# 15.0  120.7  111.8  102.9   94.4
# 20.0  128.3  120.3  112.2  105.1
# 25.0  133.6  126.5  119.4  112.7

# %%
pandas.DataFrame(T10, columns = numpy.ndarray.tolist(S10), index = numpy.ndarray.tolist(P10))
# Out:
#               0.20          0.35          0.50          0.65
# 5.0   10271.745975   8480.261425   7401.046544   6664.794479
# 10.0  20243.491951  16660.522849  14502.093089  13029.588958
# 15.0  30215.237926  24840.784274  21603.139633  19394.383437
# 20.0  40186.983901  33021.045699  28704.186178  25759.177916
# 25.0  50158.729877  41201.307123  35805.232722  32123.972395

# %%
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

pyplot.rcParams['font.family'] = 'serif'
pyplot.rcParams['font.size'] = 15

melt_depth = MD10
speeds = S10*1000
powers = P10
Tmax = T10/1e3
Z = melt_depth     
X, Y = np.meshgrid(speeds, powers)  

# fourth dimension - colormap
# create colormap according to x-value 
color_dimension = Tmax # change to desired fourth dimension
minn, maxx = color_dimension.min(), color_dimension.max()
norm = matplotlib.colors.Normalize(minn, maxx)
m = pyplot.cm.ScalarMappable(norm = norm, cmap='rainbow')
m.set_array([])
fcolors = m.to_rgba(color_dimension)

fig = plt.figure(figsize  = (10, 13), dpi=300)
ax = fig.gca(projection='3d')
fa = ax.plot_surface(X,Y,Z, rstride=1, cstride=1, facecolors=fcolors, vmin=minn, vmax=maxx, shade=False)
ax.set_xlabel('V ($mm/s$)', labelpad = 10) ; ax.set_ylabel('P ($W$)', labelpad = 10) ; 
ax.set_zlabel('$D_{max}$ ($\mu m$)', labelpad = 10)
ax.set_yticks(powers) ; ax.set_xticks(speeds);
#colorb = fig.colorbar(m, orientation="horizontal",fraction = 0.15, pad = 0.05, shrink = 0.7) ;
colorb = fig.colorbar(m, orientation="horizontal", fraction = 0.15, shrink = 0.7,pad = 0.02 )
#colorb.formatter.set_powerlimits((0,0))
colorb.set_label(r'$T_{max} \ \times 10^{3}$ ($K$)', labelpad = 20)
pyplot.savefig('3DSurfaceSF.png', )
# cbaxes = fig.add_axes([0, 0, 0.03, 0.8]) 
# cb = plt.colorbar(m, cax = cbaxes)
